# %% [markdown]
# <a href="https://colab.research.google.com/github/MileideNovais/Mileide-Novais/blob/main/desafio_machi_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/datasets/Salary.csv')

# %%
import requests
import json

# %%
#endpoint URL
url = "https://as5jmctylk.execute-api.us-east-1.amazonaws.com/default/demo_forecast"

# %%
#data: years of experience
data ={ "Nome": 0,
       "Nome2": 1}

# %%
#POST request to machine Learning API
request = requests.post(url, data=json.dumps(data))

# %%
#extract response as JSON: salary forecast
response = request.json()

# %%
print(response)
# Out:
# {'Nome': 28859.53, 'Nome2': 37591.47}

# %%
salary = 28859.53 + 8731.94*1
salary
# Out:
# 37591.47

# %%
df.shape
# Out:
# (35, 2)

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        35.000000      35.000000
# mean          6.308571   83945.600000
# std           3.618610   32162.673003
# min           1.100000   37731.000000
# 25%           3.450000   57019.000000
# 50%           5.300000   81363.000000
# 75%           9.250000  113223.500000
# max          13.500000  139465.000000

# %%
df ['Salary/YearsExperience'] = df['Salary']/df['YearsExperience']
df
# Out:
#     YearsExperience  Salary  Salary/YearsExperience
# 0               1.1   39343            35766.363636
# 1               1.3   46205            35542.307692
# 2               1.5   37731            25154.000000
# 3               2.0   43525            21762.500000
# 4               2.2   39891            18132.272727
# 5               2.9   56642            19531.724138
# 6               3.0   60150            20050.000000
# 7               3.2   54445            17014.062500
# 8               3.2   64445            20139.062500
# 9               3.7   57189            15456.486486
# 10              3.9   63218            16209.743590
# 11              4.0   55794            13948.500000
# 12              4.0   56957            14239.250000
# 13              4.1   57081            13922.195122
# 14              4.5   61111            13580.222222
# 15              4.9   67938            13864.897959
# 16              5.1   66029            12946.862745
# ...

# %%
df.describe()
# Out:
#        YearsExperience         Salary  Salary/YearsExperience
# count        35.000000      35.000000               35.000000
# mean          6.308571   83945.600000            15770.651334
# std           3.618610   32162.673003             6035.927914
# min           1.100000   37731.000000            10330.740741
# 25%           3.450000   57019.000000            12097.573838
# 50%           5.300000   81363.000000            13864.897959
# 75%           9.250000  113223.500000            16611.903045
# max          13.500000  139465.000000            35766.363636

# %%
df.groupby(['YearsExperience','Salary'])['Salary/YearsExperience'].max()
# Out:
# YearsExperience  Salary
# 1.1              39343     35766.363636
# 1.3              46205     35542.307692
# 1.5              37731     25154.000000
# 2.0              43525     21762.500000
# 2.2              39891     18132.272727
# 2.9              56642     19531.724138
# 3.0              60150     20050.000000
# 3.2              54445     17014.062500
#                  64445     20139.062500
# 3.7              57189     15456.486486
# 3.9              63218     16209.743590
# 4.0              55794     13948.500000
#                  56957     14239.250000
# 4.1              57081     13922.195122
# 4.5              61111     13580.222222
# 4.9              67938     13864.897959
# 5.1              66029     12946.862745
# 5.3              83088     15676.981132
# 5.9              81363     13790.338983
# 6.0              93940     15656.666667
# 6.8              91738     13490.882353
# 7.1              98273     13841.267606
# 7.9              101302    12823.037975
# ...

# %%
df[df['Salary/YearsExperience']==df['Salary/YearsExperience'].min()]
# Out:
#     YearsExperience  Salary  Salary/YearsExperience
# 34             13.5  139465            10330.740741

# %%
cond = df['YearsExperience']== 0
cond
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# Name: YearsExperience, dtype: bool

# %%
df[cond]
# Out:
#     YearsExperience  Salary  Salary/YearsExperience
# 0                 0   39343            35766.363636
# 1                 0   46205            35542.307692
# 2                 0   37731            25154.000000
# 3                 0   43525            21762.500000
# 4                 0   39891            18132.272727
# 5                 0   56642            19531.724138
# 6                 0   60150            20050.000000
# 7                 0   54445            17014.062500
# 8                 0   64445            20139.062500
# 9                 0   57189            15456.486486
# 10                0   63218            16209.743590
# 11                0   55794            13948.500000
# 12                0   56957            14239.250000
# 13                0   57081            13922.195122
# 14                0   61111            13580.222222
# 15                0   67938            13864.897959
# 16                0   66029            12946.862745
# ...

# %%
df[cond].describe()
# Out:
#        YearsExperience         Salary  Salary/YearsExperience
# count             35.0      35.000000               35.000000
# mean               0.0   83945.600000            15770.651334
# std                0.0   32162.673003             6035.927914
# min                0.0   37731.000000            10330.740741
# 25%                0.0   57019.000000            12097.573838
# 50%                0.0   81363.000000            13864.897959
# 75%                0.0  113223.500000            16611.903045
# max                0.0  139465.000000            35766.363636
